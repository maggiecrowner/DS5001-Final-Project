# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiecrowner/DS5001-Final-Project/blob/main/TFIDF_L2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Derived Tables - TFIDF_L2

# %%
! git clone https://github.com/maggiecrowner/DS5001-Final-Project.git
# Out:
# Cloning into 'DS5001-Final-Project'...
# remote: Enumerating objects: 275, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 275 (delta 57), reused 4 (delta 4), pack-reused 175 (from 1)
# Receiving objects: 100% (275/275), 15.06 MiB | 11.69 MiB/s, done.
# Resolving deltas: 100% (108/108), done.

# %%
# !wget -O TFIDF.csv "https://virginia.box.com/shared/static/cieo8adcs24q8bhd3wdxmjcv47dor6c7.csv"
# !wget -O DTM.csv "https://virginia.box.com/shared/static/9g0v251d9103gw4xibbhwvks7m9pc2d2.csv"
# Out:
# --2026-04-21 02:22:20--  https://virginia.box.com/shared/static/cieo8adcs24q8bhd3wdxmjcv47dor6c7.csv
# Resolving virginia.box.com (virginia.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to virginia.box.com (virginia.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/cieo8adcs24q8bhd3wdxmjcv47dor6c7.csv [following]
# --2026-04-21 02:22:20--  https://virginia.box.com/public/static/cieo8adcs24q8bhd3wdxmjcv47dor6c7.csv
# Reusing existing connection to virginia.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://virginia.app.box.com/public/static/cieo8adcs24q8bhd3wdxmjcv47dor6c7.csv [following]
# --2026-04-21 02:22:21--  https://virginia.app.box.com/public/static/cieo8adcs24q8bhd3wdxmjcv47dor6c7.csv
# Resolving virginia.app.box.com (virginia.app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# ...

# %%
import pandas as pd
TFIDF = pd.read_csv('TFIDF.csv', delimiter='|', index_col=[0,1,2])
DTM = pd.read_csv('DTM.csv', delimiter='|', index_col=[0,1,2])

# %%
from numpy.linalg import norm

TFIDF_L2 = TFIDF.apply(lambda x: x / norm(x), 1)

# Keep only words that appear in at least 2 documents
DF = DTM.astype('bool').sum()
TFIDF_L2 = TFIDF_L2.loc[:, DF >= 2]

TFIDF_L2.head()
# Out:
#                                                                                       a  \
# Artist        Album                                 Title
# Ariana Grande 13 (Original Broadway Cast Recording) Brand New You              0.022310
#               Ariana Grande                         Ariana Grande Tour Guide   0.000000
#                                                     I’m Every Woman/Vogue      0.020322
#                                                     Leave Me Lonely (Reprise)  0.013772
#                                                     Love Me Harder/breathin    0.001267
#
#                                                                                     all  \
# Artist        Album                                 Title
# Ariana Grande 13 (Original Broadway Cast Recording) Brand New You              0.020347
#               Ariana Grande                         Ariana Grande Tour Guide   0.000000
# ...

# %%
print("Number of features:", TFIDF_L2.shape[1])
# Out:
# Number of features: 8350

# %%
TFIDF_L2.to_csv('/content/DS5001-Final-Project/TFIDF_L2.csv', sep='|', index=True)
