# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiecrowner/DS5001-Final-Project/blob/main/BOW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Derived Tables - BOW

# %%
! git clone https://github.com/maggiecrowner/DS5001-Final-Project.git
# Out:
# Cloning into 'DS5001-Final-Project'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 266 (delta 51), reused 4 (delta 4), pack-reused 175 (from 1)
# Receiving objects: 100% (266/266), 15.05 MiB | 10.25 MiB/s, done.
# Resolving deltas: 100% (102/102), done.

# %%
# !wget -O CORPUS.csv "https://virginia.box.com/shared/static/ijkqovrdgvrmctsdqobymig2p98q9x0m.csv"
# Out:
# --2026-04-21 02:11:01--  https://virginia.box.com/shared/static/ijkqovrdgvrmctsdqobymig2p98q9x0m.csv
# Resolving virginia.box.com (virginia.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to virginia.box.com (virginia.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/ijkqovrdgvrmctsdqobymig2p98q9x0m.csv [following]
# --2026-04-21 02:11:02--  https://virginia.box.com/public/static/ijkqovrdgvrmctsdqobymig2p98q9x0m.csv
# Reusing existing connection to virginia.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://virginia.app.box.com/public/static/ijkqovrdgvrmctsdqobymig2p98q9x0m.csv [following]
# --2026-04-21 02:11:02--  https://virginia.app.box.com/public/static/ijkqovrdgvrmctsdqobymig2p98q9x0m.csv
# Resolving virginia.app.box.com (virginia.app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to virginia.app.box.com (virginia.app.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!be4cO_8EPPPnWRBcBPYD-ArcZdvQZXZGlXdAxva-0gtCH-FJvgT1eYfxLkGOxMQBJycFSSHJ5BjTbQpPoXtXZ0pB4Mk6MBoQQj6Et3qsaJmRwalyuvy8KYyB3CQj3KBrNsjz6i7UKya5f0796oZGITYU3U-A0HE__1HB_BFCej3Q8j7ErxvJ-8LgkRULbG2_1lUq4h3FT8RH8QIS4WiMGFCJwDN4Q6Ap6STnyq7I2TdQiRScUApmOIhX3KC6MRjDqiobDY00f6mAycdGrc6BBhUKH5jH-DMdq-o-DZ_kne5BJ78b6K6UPS35adS6QbuwWBjtAUbTGzd50ch9MXixprZsC9dxsrOHUj4oUekCU6Tv6joRYKC-kxWSWCTVxrQi2Rq7ESkxE-NdCVezx9Uz9dSjRTtfEG0mn7_BvhhAFCnLPxXTp2aHFbDtPthl6gH41OqhrAeS9o5FPFO8JYnlubq-YIx30QxzYiOHrr-uc1IVL9clGsURSDANEs2-WAScHa_OL_wWjllbXz_QyAPIfpvKPcg2b-x4Sle8zJumJwtTWcuLnSUKsx5HfjMg0gCKCYC0Kdqi5Db5jMdKnNkQqkVdcc6g76xrkry2bThR5rs56j9tiQ3yXc78OiA8OMFq3MAB4-otPyjI4CYd0juM848xXpsxgz
PyjI4CYd0juM848xXpsxgzNnort9rMpTbwxweLDx06JM3gcSreSoShABtgxVNu5nLbmnljjYTUrWD_tEI6-eD4k40Bj_4txHTx39M-ceMz9b9LgCTrqO9sMC5d0Wsye9DulafDUbZRMjnD1ElM7-rHVB7weDDz7HSIs0FFrH8fh0qJOjqlv8xRwpFt0jbUBI02ZddrCpAY6itzq-k59nWhpvcoIKT_BumyQz_pyNrpAJqu1dTR-WLQ81IoaSaVjiv-mYxKwBH_ZmIW-oLDCVUcjfpYHVIwtw_kZw6HBPbRN5rv_L1OW1HPYLJqqh4Lr82HdWzuR5p7xULwEiJ-rrL9PoUMX-0g7ftWJeWy5RaLPyn39Wc7_8JQPAM-dy_8kpUDatbfwvSa_h61i05h2aAnEawz1Iioz7ZRM5i8mLuGVvUiMzHmorRpDGekHMYoWgvoSpCEOzBauOlmTG6xxN4_lcHhHUpPYp5XbjvAe2l0q8uU3uAR2uIUgkSn-cCV9Ac0LXfcZR395clvOojibZngqX0SaatuYrd-k5SdnVV0mB_UMF6lZkZgH5ujaYmUErb-69zxiMVbic9tB6wTlThgb-ameZ5jS93RrS3qxGNV741rCKwf_5ma07Sf1o1OUPxjRu6iuY9kVGey2EyzhFLDxC84csSZ9LqWGxBQJAIF7TDL3JSIDsB4CX3ylgTI9K1Bj1SIwZHWEefnABul7K2PhZHeiQR6mI4GEuq2M0alsxMQmd40PTrmr5FRmp6VTpq-MSCNS6SLliVjeLvbcHDvnltWKERFMgxLkDReMdX7KaD6u4JCapeBMUghBZfu0lPlDNWgEeYyjCAK8L/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 74.112.186.165, 2620:117:bff0:69::
# Connecting to public.boxcloud.com (public.boxcloud.com)|74.112.186.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69963573 (67M) [text/csv]
# Saving to: ‘CORPUS.csv’
#
# CORPUS.csv          100%[===================>]  66.72M   141MB/s    in 0.5s
#
# 2026-04-21 02:11:03 (141 MB/s) - ‘CORPUS.csv’ saved [69963573/69963573]

# %%
import pandas as pd
CORPUS = pd.read_csv('CORPUS.csv', delimiter='|')

# %%
OHCO = ['Artist', 'Album', 'Title', 'token_str']
bags = dict(
    TITLES = OHCO[:3],
    ALBUMS = OHCO[:2],
    ARTISTS = OHCO[:1]
)

# %%
def create_bow(CORPUS, bag):
    bow = (
        CORPUS
        .groupby(bags[bag]+['term_str'])
        .term_str.count()
        .to_frame('n')
    )
    return bow

# %%
BOW = create_bow(CORPUS, bag='TITLES')
BOW.head()
# Out:
#                                                                              n
# Artist        Album                                 Title         term_str
# Ariana Grande 13 (Original Broadway Cast Recording) Brand New You a         18
#                                                                   all        6
#                                                                   and        9
#                                                                   around     2
#                                                                   at         2

# %%
print('Number of observations:', len(BOW))
# Out:
# Number of observations: 235266

# %%
BOW.to_csv('/content/DS5001-Final-Project/BOW.csv', sep='|', index=True)
