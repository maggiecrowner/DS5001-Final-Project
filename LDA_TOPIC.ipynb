# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiecrowner/DS5001-Final-Project/blob/main/LDA_TOPIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LDA TOPIC

# %%
! git clone https://github.com/maggiecrowner/DS5001-Final-Project.git
# Out:
# Cloning into 'DS5001-Final-Project'...
# remote: Enumerating objects: 293, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 293 (delta 68), reused 4 (delta 4), pack-reused 175 (from 1)
# Receiving objects: 100% (293/293), 15.09 MiB | 5.24 MiB/s, done.
# Resolving deltas: 100% (119/119), done.

# %%
# !wget -O PHI.csv "https://virginia.box.com/shared/static/w4j0xqikvfp8qj9obnsprf6peluoo64o.csv"
# !wget -O THETA.csv "https://virginia.box.com/shared/static/xap24wuixe7l1gm0xnhywtddmfmij38e.csv"
# Out:
# --2026-04-21 02:46:11--  https://virginia.box.com/shared/static/w4j0xqikvfp8qj9obnsprf6peluoo64o.csv
# Resolving virginia.box.com (virginia.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to virginia.box.com (virginia.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/w4j0xqikvfp8qj9obnsprf6peluoo64o.csv [following]
# --2026-04-21 02:46:11--  https://virginia.box.com/public/static/w4j0xqikvfp8qj9obnsprf6peluoo64o.csv
# Reusing existing connection to virginia.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://virginia.app.box.com/public/static/w4j0xqikvfp8qj9obnsprf6peluoo64o.csv [following]
# --2026-04-21 02:46:11--  https://virginia.app.box.com/public/static/w4j0xqikvfp8qj9obnsprf6peluoo64o.csv
# Resolving virginia.app.box.com (virginia.app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# ...

# %%
import pandas as pd
THETA = pd.read_csv('THETA.csv', delimiter='|', index_col=[0,1,2])
PHI = pd.read_csv('PHI.csv', delimiter='|', index_col=0)

# %%
n_top_terms = 5
TOPICS = PHI.stack().groupby('topic_id')\
    .apply(lambda x: ' '.join(x.sort_values(ascending=False).head(n_top_terms).reset_index().term_str))\
    .to_frame('top_terms')
TOPICS['mean_doc_weight'] = THETA.mean()
TOPICS = TOPICS.sort_values('mean_doc_weight', ascending=False)

# %%
labels = {
    'T18': 'Introspection',
    'T02': 'Daily Life',
    'T07': 'Longing',
    'T13': 'Romance',
    'T06': 'Ad-libs',
    'T14': 'Beyonce',
    'T10': 'Night',
    'T19': 'Ariana Grande',
    'T04': 'Pop',
    'T08': 'R&B',
    'T09': 'Uplifting',
    'T12': 'Holiday',
    'T15': 'Drama',
    'T11': 'Rap',
    'T00': 'Feminine',
    'T17': 'Justin Bieber',
    'T05': 'Vague',
    'T03': 'Confidence',
    'T01': 'Dance',
    'T16': 'Lady Gaga'
}

TOPICS['best_guess_label'] = TOPICS.index.map(labels)
TOPICS.to_csv("/content/DS5001-Final-Project/TOPICS.csv", sep="|", index=True)

# %% [markdown]
# LDA and PCA Visualization code in https://github.com/maggiecrowner/DS5001-Final-Project/blob/main/Models2.ipynb
