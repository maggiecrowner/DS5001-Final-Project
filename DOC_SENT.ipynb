# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiecrowner/DS5001-Final-Project/blob/main/DOC_SENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment - DOC_SENT

# %%
! git clone https://github.com/maggiecrowner/DS5001-Final-Project.git
# Out:
# Cloning into 'DS5001-Final-Project'...
# remote: Enumerating objects: 305, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 305 (delta 74), reused 4 (delta 4), pack-reused 175 (from 1)
# Receiving objects: 100% (305/305), 15.10 MiB | 15.09 MiB/s, done.
# Resolving deltas: 100% (125/125), done.

# %%
# !wget -O BOW_SENT.csv "https://virginia.box.com/shared/static/6xr0mdmmc7rz5lz0invby3sonn5139wv.csv"
# Out:
# --2026-04-21 03:07:29--  https://virginia.box.com/shared/static/6xr0mdmmc7rz5lz0invby3sonn5139wv.csv
# Resolving virginia.box.com (virginia.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to virginia.box.com (virginia.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/6xr0mdmmc7rz5lz0invby3sonn5139wv.csv [following]
# --2026-04-21 03:07:29--  https://virginia.box.com/public/static/6xr0mdmmc7rz5lz0invby3sonn5139wv.csv
# Reusing existing connection to virginia.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://virginia.app.box.com/public/static/6xr0mdmmc7rz5lz0invby3sonn5139wv.csv [following]
# --2026-04-21 03:07:29--  https://virginia.app.box.com/public/static/6xr0mdmmc7rz5lz0invby3sonn5139wv.csv
# Resolving virginia.app.box.com (virginia.app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# ...

# %%
import pandas as pd
BOW_SENT = pd.read_csv('BOW_SENT.csv', delimiter='|', index_col=["Artist", "Album", "Title", "term_str"])

# %%
DOC_SENT = (
    BOW_SENT
    .groupby(["Artist", "Album", "Title"])
    .agg(
        sentiment_sum    = ("sentiment_weighted", "sum"),
        sentiment_mean   = ("sentiment_weighted", "mean"),
        sentiment_tokens = ("n", "sum"),
    )
    .reset_index()
)

DOC_SENT["sentiment_norm"] = DOC_SENT["sentiment_sum"] / DOC_SENT["sentiment_tokens"]
DOC_SENT.head()
# Out:
#           Artist                                  Album  \
# 0  Ariana Grande  13 (Original Broadway Cast Recording)
# 1  Ariana Grande                          Ariana Grande
# 2  Ariana Grande                          Ariana Grande
# 3  Ariana Grande                          Ariana Grande
# 4  Ariana Grande                          Ariana Grande
#
#                        Title  sentiment_sum  sentiment_mean  sentiment_tokens  \
# 0              Brand New You            9.0        1.125000                10
# 1   Ariana Grande Tour Guide           -4.0       -1.000000                 5
# 2      I’m Every Woman/Vogue            7.0        0.411765                28
# 3  Leave Me Lonely (Reprise)          -18.0       -2.571429                18
# 4    Love Me Harder/breathin           18.0        1.800000                20
#
#    sentiment_norm
# 0            0.90
# 1           -0.80
# 2            0.25
# 3           -1.00
# 4            0.90

# %%
DOC_SENT.to_csv("/content/DS5001-Final-Project/DOC_SENT.csv", sep="|", index=True)

# %% [markdown]
# Code for Sentiment Visualization Plot in https://github.com/maggiecrowner/DS5001-Final-Project/blob/main/Sentiment.ipynb
